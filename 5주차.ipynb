# %% [markdown]
# <a href="https://colab.research.google.com/github/shinyehwan/python_basic/blob/main/5%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#파이썬 자료구조
#리스트, 튜플, 딕셔너리, 세트


#리스트 만들기 -> 추가, 수정, 삭제 가능(오로지 순서)
#대괄호를 사용하여 리스트를 선언할 수 있음
#어떤 자료형이라도 리스트에 들어갈 수 있음
L1 = [5, 8, 3, 2, 10] 

print(L1)

L2 = [-3, "단국대학교", "FPGA실험", True, 3.14]

print(L2)


#빈 리스트 만들기

empty_L1 = []
empty_L2 = list()

print(empty_L1, empty_L2)

#튜플 만들기 -> 리스트랑 똑같은데 변경불가능, 한번 만들어지면 추가, 삭제 불가능
#소괄호를 사용하여 튜플을 선언할 수 있음
#어떤 자료형이라도 튜플에 들어갈 수 있음
T1 = (5, 8, 3, 2, 10)

print(T1)

#빈 튜플 만들기

empty_T1=()
empty_T2=tuple()

print(empty_T1, empty_T2)

# 리스트 <-> 튜플
# 리스트는 변경 가능, 튜플은 변경 불가능한 특징

# 리스트 -> 튜플
print(tuple(L1)) 


# 튜플 -> 리스트
print(list(T1))



#딕셔너리(사전형)
#key : value 형식
D1 = {"key1" : "value1", 'key2' : 'value2'}

print(D1)

#빈 딕셔너리 만들기

empty_D1={}
empty_D2=dict()

#딕셔너리 key 접근하기

print(D1["key1"])
print(D1["key2"])

#딕셔너리 key, value 할당하기

D1["key1"] = "One"
D1["key2"] = "Two"

print(D1)

#세트 만들기
#중복을 허용하지 않는다
fruits = {"grape", "orange", "banana", "apple", "cherry", "cherry"} 

print(fruits)



#조건문
# 들여쓰기가 상당히 중요해

x=10
if x==10:
  print(True)


x=9
if x==10:
  print("10")
elif x==9:
  print("9")
else:
  print("0")

#반복문

for i in range(10):
  print("Hello, world!")

for i in range(10):
  print('Hello, world!', i)


i=0
while i<100: #while 에 True를 지정하면 무한루프
  print('Hello, world!')
  i +=1


for i in range(10):  #0 부터 9까지 반복
  print(i)
  if i==5:
    break
i=0
while True:
  print(i)
  i += 1
  if i == 100 :
    break


for i in range(10): #0 부터 9까지 증가하면서 10번 반복
  if i % 2 == 0 : # i를 2로 나누었을때 나머지가 0 이면 True
    continue # 아래 코드를 실행하지 않고 건너뜀
  print(i)



i=0
while i < 10: #i가 10보다 작을 때 반복, 0 부터 9까지 증가하면서 10번 반복
  i+=1 # i를 1씩 증가
  if i % 2==0: # i를 2로 나누었을 때 나머지가 0이면 True
    continue # 아래코드를 실행하지 않고 건너 뜀
  print(i)
# Out:
# [5, 8, 3, 2, 10]
# [-3, '단국대학교', 'FPGA실험', True, 3.14]
# [] []
# (5, 8, 3, 2, 10)
# () ()
# (5, 8, 3, 2, 10)
# [5, 8, 3, 2, 10]
# {'key1': 'value1', 'key2': 'value2'}
# value1
# value2
# {'key1': 'One', 'key2': 'Two'}
# {'banana', 'grape', 'cherry', 'apple', 'orange'}
# True
# 9
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world! 0
# Hello, world! 1
# Hello, world! 2
# Hello, world! 3
# Hello, world! 4
# Hello, world! 5
# Hello, world! 6
# Hello, world! 7
# Hello, world! 8
# Hello, world! 9
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# ...
