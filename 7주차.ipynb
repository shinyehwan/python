# %% [markdown]
# <a href="https://colab.research.google.com/github/shinyehwan/python_basic/blob/main/7%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 함수 (메소드)
# 함수 정의하기

def hello(): # 함수 선언
  #함수 블럭 내에 코드 작성
  print("Hello, python !")

hello()

# 함수 블럭 내 pass를 사용하여 빈 함수 정의

#hello2() #hello 함수를 정의하기 전에 함수를 먼저 호출 -> 인터프리터 언어이기 때문에

#def hello2() #hello 함수 정의
#  print('hello, world!')




# 함수(메소드) - 여러 매개변수를 받는 함수

# 덧셈 함수 정의하기

def add(a, b):
  print(a+b)

add(10, 20)

# 함수(메소드) - return 사용하기기

def add(a,b):
  return a+b # 남기고 메모리 할당을 해제한다, 함수의 결과값을 변수에 할당하려면 return을 사용하라

x= add(10,20)
print(x)

# 함수(메소드) - 두개 이상의 값 리턴하기

# 두 수를 더한 값과 뺀 값을 리턴하는 함수 정의하기

def add_sub(a, b): # 매개변수
  return a+b, a-b

x, y = add_sub(10,20) # 인수
print(x,y)

z = add_sub(100,200) # 하나의 변수에 할당이 되어서
print(z) # 투플 형식으로 패킹이 되어서


# 함수(메소드) - 인수(인자, argument, arg)
# 위치 인수
# 키워드 인수
# 패킹 & 언패킹


# 위치인수
def print_numbers(a,b,c):
  print(f"a is {a}") # f -> 문자열로 바꾸어 준다, {} -> 변수명을 넣ㅇ르 수 있다.
  print(f"b is {b}")
  print(f"c is {c}")

print_numbers(10,20,30)

# 키워드 인수
def personal_info(name, age, address):
  print('이름 : ', name)
  print('나이 : ', age)
  print('주소 : ', address)


# 인수를 넣어 줄때 어떤 위치의 매개변수인지 순서를 몰라도, 키워드에 맞추어 인수를 적어주면 알아서 잘한다
personal_info('홍길동', 30, '서울시 용산구 이촌동')
personal_info(name='홍길동', age=30, address='서울시 용산구 이촌동')
personal_info(age=30, address='서울시 용산구 이촌동', name='홍길동')


# 튜플 패킹 & 언패킹
human=(180,75)
print(human)

human = 180,75
print(human)

# 언패킹
height, weight = human
print(height, weight)


def print_numbers(a,b,c):
  print(f"a is {a}") # f -> 문자열로 바꾸어 준다, {} -> 변수명을 넣ㅇ르 수 있다.
  print(f"b is {b}")
  print(f"c is {c}")

x=[10,20,30]
y=(100,200,300)
print_numbers(*x)
print_numbers(*y)
# Out:
# Hello, python !
# 30
# 30
# 30 -10
# (300, -100)
# a is 10
# b is 20
# c is 30
# 이름 :  홍길동
# 나이 :  30
# 주소 :  서울시 용산구 이촌동
# 이름 :  홍길동
# 나이 :  30
# 주소 :  서울시 용산구 이촌동
# 이름 :  홍길동
# 나이 :  30
# 주소 :  서울시 용산구 이촌동
# (180, 75)
# (180, 75)
# 180 75
# a is 10
# b is 20
# c is 30
# a is 100
# b is 200
# c is 300
